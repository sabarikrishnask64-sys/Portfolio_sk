# %%
# Extracting content from the uploaded resume document
import os
import zipfile
from xml.etree import ElementTree as ET
from pathlib import Path

file_path = Path('sk2.docx')
print(file_path.exists(), file_path)
